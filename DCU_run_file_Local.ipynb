# %%
# %pip install --upgrade pip
# %pip install --no-cache-dir -r requirements_1.txt
# Out:
# ...
#      |████████████████████████████████| 296 kB 9.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 41.4 MB 34.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 30.7 MB 149.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.1 MB 125.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 232 kB 160.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 67 kB 95.1 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 736 kB 143.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 162.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 147.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 80 kB 152.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 135.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 593 kB 126.5 MB/s eta 0:00:01
# ...

# %%
# ERROR: Cannot install -r requirements.txt (line 1), -r requirements.txt (line 155), -r requirements.txt (line 171), -r requirements.txt (line 195), -r requirements.txt (line 197), -r requirements.txt (line 51) and huggingface-hub==0.23.4 because these package versions have conflicting dependencies.

# %%
! pip install fuzzysearch
! pip install fuzzywuzzy
! pip install doctr
! pip install python-doctr
! pip install "python-doctr[tf]"
! pip install "python-doctr[torch]"
! pip install gliner
# Out:
# ...
#      |████████████████████████████████| 112 kB 1.6 MB/s eta 0:00:01
# ...
#   Created wheel for fuzzysearch: filename=fuzzysearch-0.7.3-cp38-cp38-linux_x86_64.whl size=363825 sha256=1dc1de8aa22d93cdb87e959ece03e778aad92e16761daff7d73c1786c10efbc6
#   Stored in directory: /home/cai/.cache/pip/wheels/fc/e6/eb/4c4b250a0d6562161dcb8667e2cb07a5e20b257fcb75e50b04
# Successfully built fuzzysearch
# ...
#      |████████████████████████████████| 295 kB 2.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 682 kB 57.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.4 MB 149.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 271 kB 167.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 88 kB 14.2 MB/s  eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 235 kB 151.0 MB/s eta 0:00:01
# ...

# %%
# !pip install --upgrade huggingface_hub
# Out:
# ...
#      |████████████████████████████████| 436 kB 3.1 MB/s eta 0:00:01
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.24.6
#     Uninstalling huggingface-hub-0.24.6:
#       Successfully uninstalled huggingface-hub-0.24.6
# ...

# %%
import os
import re
import time
from pathlib import Path
import flair
os.environ['FLAIR_CACHE_ROOT'] = './cache'
flair.cache_root = Path(os.environ['FLAIR_CACHE_ROOT']+"/home/cai/.flair")
# Out:
# 2024-09-18 10:16:36.537194: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-18 10:16:38.372056: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-18 10:16:40.145828: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from dfs.commons import constants
from dfs.commons.ioutils.datastore_utils import read_from_data_lake
from dfs.commons import constants
# from dfs.core.pdf_non_gen import run_single_module
# from dfs.core.pdf_non_gen import main
from dfs.core.pdf_non_gen_run_info import main
# Out:
# 2024-09-18 10:16:52,237 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2024-09-18 10:16:56,211 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>

# %% [markdown]
# <div style="background-color:Teal">---------------------------------------</div>
#
# <div style="background-color:lightblue ;color: red;font-style:Bold;font-size: 16px"> Run All Module: </div>
#
# <div style="background-color:Teal">---------------------------------------</div>

# %% [markdown]
# <div style="background-color:Teal">---------------------------------------</div>
#
# <div style="background-color:Teal">Define Local file path to be process</div>
#
# <div style="background-color:Teal">---------------------------------------</div>

# %%
input_file_path = "/home/cai/anlsts_exl_isc_minerva_Poc_2c0551ba_Sol_21/Sitaram/exl-ds-document-fraud-core_v5/pdf_input/Doc Fraud Test 1 1.pdf"
# input_file_path = "/home/cai/anlsts_exl_isc_minerva_Poc_2c0551ba_Sol_21/Sitaram/exl-ds-document-fraud-core_v5/pdf_input/00096974332.pdf"
# input_json_filename = "/home/cai/anlsts_exl_isc_minerva_Poc_2c0551ba_Sol_21/Sitaram/exl-ds-document-fraud-core_v5/pdf_input/80b8a52b-717d-4619-8e88-ff75fe6a0c8d.json"
# input_file_path = "/home/cai/anlsts_exl_isc_minerva_Poc_2c0551ba_Sol_21/Sitaram/exl-ds-document-fraud-core_v5/pdf_input/00097049799.pdf"
# input_file_path = "/home/cai/anlsts_exl_isc_minerva_Poc_2c0551ba_Sol_21/Sitaram/exl-ds-document-fraud-core_v5/pdf_input/Receipt-623673.pdf"

input_json_filename = ''

# check json exist
from pathlib import Path
file_path = Path(input_json_filename)
if file_path.is_file():
    print(f"The file at '{file_path}' exists.")
else:
    print(f"The file at '{file_path}' does not exist.")

# %% [markdown]
# <div style="background-color:Teal">---------------------------------------</div>
# <div style="background-color:Teal">Define output file/folder path</div>
# <div style="background-color:Teal">---------------------------------------</div>

# %%
output_base_dir = "/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_output/"
# input_file_path = "/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_input/annotated/20223656001361USD_BOA.pdf"
input_file_path = "/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_input/729ea90729384405a60728f621d122eb.pdf"

input_json_filename = ''
bank_name = 'navy federal credit union'

# %%
import time
st=time.time()
four_corner_analysis_run = 0
# main(pdf_file_path, json_file_path, output_base_dir,  four_corner_run, bank_name,strategy="sequential")
main(input_file_path, input_json_filename, output_base_dir, four_corner_analysis_run, bank_name, strategy="sequential")
time = time.time()-st
print('file Run Time------',time/60)
# Out:
# DIGITAL PDF
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [6], line 5
#       3 four_corner_analysis_run = 0
#       4 # main(pdf_file_path, json_file_path, output_base_dir,  four_corner_run, bank_name,strategy="sequential")
# ----> 5 main(input_file_path, input_json_filename, output_base_dir, four_corner_analysis_run, bank_name, strategy="sequential")
#       6 time = time.time()-st
#       7 print('file Run Time------',time/60)
#
# File ~/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/dfs/core/pdf_non_gen_run_info.py:808, in main(input_file_path, input_json_filename, output_base_dir, four_corner_run, bank_name_excel_path, strategy)
#     806 prep_time = time.time() - run_time
#     807 run_data_df['Directory_Creation_Time'] = prep_time
# --> 808 run_all_modules(input_file_path, input_json_filename, bank_name_excel_path, fraud_report_file_path,
# ...

# %% [markdown]
# <div style="background-color:Teal">---------------------------------------</div>
#
# <div style="background-color:lightblue ;color: red;font-style:Bold;font-size: 16px"> Multifile processing: </div>
#
# <div style="background-color:Teal">---------------------------------------</div>

# %% [markdown]
# <div style="background-color:Teal">---------------------------------------</div>
#
# <div style="background-color:Teal">Define folder path to be process</div>
#
# <div style="background-color:Teal">---------------------------------------</div>

# %%
# Define Local folder path to be process
# root_directory = Path("/home/cai/anlsts_exl_isc_minerva_Poc_2c0551ba_Sol_21/Sitaram/common_pdf")
root_directory = Path("/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_input")


pdf_list = []
# pdf_files = os.listdir(root_directory)
pdf_files = [file for file in os.listdir(root_directory) if file.lower().endswith(".pdf")]
count = 0
for file in pdf_files:
    file_path = re.sub(r"\.pdf$", "", file)
    pdf_list.append(file_path)
    count+=1

# print(pdf_list)
print(f"Total processed file Count--{count}nos")
# Out:
# Total processed file Count--503nos

# %%
pdf_list[236:250]
# Out:
# ['677715c24a53456babe0ce92272d22b2',
#  'b9c65dc015304a4fbf30b882e81a3184',
#  '6d7e5241641947eaa0d80da7f20ac4bd',
#  'CL-01KCWHL',
#  'Chase_AUGOST',
#  '2023177CD76094USD-Forzatelecom npc inc March 23',
#  '23180MQMQ738082',
#  'e5e3b59bfe034bfd823371aa79cfb618',
#  '23145E3W2029293646',
#  '23122E3W3045911081',
#  '23146E3W4035329790',
#  '653192997aa44ad8a659fb494773c4b7',
#  'griffin-portal-download-b322888b-0cd5-48fa-9e52-b50ce17af1ec-4673',
#  '0f5fcd3ea5b946b2a4445460403b357f']

# %%
import pandas as pd
import time
st = time.time()

input_pdf_file_path = "/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_input/"

input_json_file_path = ""

output_base_dir = "/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_output_09_17/"


file_path = '/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/Repo/bank_name.xlsx'
# Read the Excel file for bank name
df = pd.read_excel(file_path)

first_100_files = pdf_list[236:250]
# print(len(first_100_files))

four_corner_run = 0

count = 0
for path in first_100_files:
    if path not in ('22161SFR4068373127', '35ff8bd09a754ab29f049dc66ce58143', '3c25adfa422141cbb5e4bd6432683a8b', '23135E3W2029272895', 'ed8933e2654b425eac36f21b6cb53692','ef1f045675714ae8a5a16fee91e3e987','edcb9b7703814f6bb284ef98323d9f53','ef23c7513ed84466857a4270626d9616','ef2abfc32066468b91eadd764391953a'):
        # st1 = time.time()
        pdf_file_path = Path(f"{input_pdf_file_path}{path}.pdf")
        count+=1
        pdf_filename_file = path
        print(pdf_file_path)
        # print(f"The file at '{json_file_path}' does not exist.")
        json_file_path = ''
        bank_name = df[df['filename'] == pdf_filename_file]['bank_name'].values[0]
        try:
            main(pdf_file_path, json_file_path, output_base_dir,  four_corner_run, bank_name,strategy="sequential")
            # print(f"File processing Time----{(time.time()-st1)/60}min")
        except:
            print('found error---------------')
            print('error file----------------',pdf_file_path)
        # print(f"Processing Time----{time/60}min")

time = time.time() - st
print(f"Total processed file Count--{count}nos")
print(f"Total processing file Time----{time/60}min")
# Out:
# /home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_input/677715c24a53456babe0ce92272d22b2.pdf
# pdf file is detected
# Starting tampering detection analysis...
#
# Step 1: Performing Error Level Analysis (ELA) to detect new text added
#
#
# Step 2: Proceeding with Pattern Noise Residual (PRNU) analysis.
#
# It is a clean Image, no new text is found
#
# Clean PDF File
# json_output_path
# Reconciliation Module: json file not available
# /home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_input/b9c65dc015304a4fbf30b882e81a3184.pdf
# DIGITAL PDF
# pdf file is detected
# main_logo running
# pnc bank
# pnc bank
# Clean PDF File
# Language Module-json file not available
# Language checked
# json_output_path
# Reconciliation Module: json file not available
# /home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_input/6d7e5241641947eaa0d80da7f20ac4bd.pdf
# DIGITAL PDF
# pdf file is detected
# main_logo running
# ...

# %%
first_100_files = ['22161SFR4068373127']

# %%
import pandas as pd
import time
st = time.time()

input_pdf_file_path = "/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_input/"

input_json_file_path = ""

output_base_dir = "/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_output_09_17/"


file_path = '/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/Repo/bank_name.xlsx'
# Read the Excel file for bank name
df = pd.read_excel(file_path)

# first_100_files = pdf_list[30:38]
# print(len(first_100_files))

four_corner_run = 0

count = 0
for path in first_100_files:
    if path not in ('22161SFR4068373127', '35ff8bd09a754ab29f049dc66ce58143', '3c25adfa422141cbb5e4bd6432683a8b', '23135E3W2029272895','ed8933e2654b425eac36f21b6cb53692','ef1f045675714ae8a5a16fee91e3e987','edcb9b7703814f6bb284ef98323d9f53','ef23c7513ed84466857a4270626d9616','ef2abfc32066468b91eadd764391953a'):
        st1 = time.time()
        pdf_file_path = Path(f"{input_pdf_file_path}{path}.pdf")
        count+=1
        pdf_filename_file = path
        # print(f"The file at '{json_file_path}' does not exist.")
        json_file_path = ''
        print(pdf_filename_file)
        bank_name = df[df['filename'] == pdf_filename_file]['bank_name'].values[0]
        try:
            main(pdf_file_path, json_file_path, output_base_dir,  four_corner_run, bank_name,strategy="sequential")
            print(f"File processing Time----{(time.time()-st1)/60}min")
        except:
            print('found error---------------')
            print('error file----------------',pdf_file_path)
        # print(f"Processing Time----{time/60}min")

time = time.time() - st
print(f"Total processed file Count--{count}nos")
print(f"Total processing file Time----{time/60}min")
# Out:
# Total processed file Count--0nos
# Total processing file Time----0.0005330642064412435min

# %%
Kernel Restarting file  - ['22161SFR4068373127', '35ff8bd09a754ab29f049dc66ce58143', '3c25adfa422141cbb5e4bd6432683a8b', '23135E3W2029272895']

# %%
729ea90729384405a60728f621d122eb- RuntimeError: object out of range (0 0 R); xref size 4468 [doc_type-digital, Bank name -navy federal credit union, page_count - 3]

error_file_list = ['22161SFR4068373127', '35ff8bd09a754ab29f049dc66ce58143', '3c25adfa422141cbb5e4bd6432683a8b', '23135E3W2029272895','ed8933e2654b425eac36f21b6cb53692','ef1f045675714ae8a5a16fee91e3e987','edcb9b7703814f6bb284ef98323d9f53','ef23c7513ed84466857a4270626d9616','ef2abfc32066468b91eadd764391953a']
len(error_file_list)
# Out:
# 9

# %%
l = os.listdir('/home/cai/anlsts_exl_isc_minerva_poc_64_b31bb0a5_Sol_26/Saurabh/Amex_POC/pdf_output_09_17/pdf_files')
len(l)
l1 = []
for f in l:
    l1.append(f.replace("_language_output.pdf", ""))

l2=[]
for s in pdf_list[0:250]:
    if s not in l1:
        l2.append(s)
